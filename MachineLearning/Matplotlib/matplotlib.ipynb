# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4,5]

# %%
y = [10,12,23,45,67]

# %%
plt.plot(x, y);

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x, y)
plt.show()

# %%
fig , ax = plt.subplots()
ax.plot(x ,[50,100,150,100,250]);

# %%
# import
# %matplotlib inline
import matplotlib.pyplot as plt
# prepare data
x = [1,2,3,5,6,7]
y = [12, 10, 16,17,18,20]
# setup
fig, ax = plt.subplots()
# plot 
ax.plot(x,y);
# custom
ax.set(title="Simple Plot", xlabel="X axis", ylabel="y axis")
# save
fig.savefig("simple plot.png")

# %% [markdown]
# ## Numpy matplotlib

# %%
import numpy as np

# %%
np
# Out:
# <module 'numpy' from 'G:\\Scripts\\mlds\\.env\\lib\\site-packages\\numpy\\__init__.py'>

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
fig ,ax = plt.subplots()
ax.plot(x, x**2)
ax.set(title="simple plot exp")
# Out:
# [Text(0.5, 1.0, 'simple plot exp')]

# %%
fig, ax= plt.subplots()
ax.scatter(x ,np.exp(x));

# %%
fig2, ax2 = x
ax2.scatter(x, np.sin(x));

# %% [markdown]
# # make plot from dict

# %%
nut_butter = {'Almond butter ': 10, "Peanut butter":8, "salt butter":12}

# %%
fig, ax = plt.subplots()
ax.bar(nut_butter.keys(),nut_butter.values())
ax.set(title="Nut butter values", ylabel="Price", );

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("../Pandas/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] =car_sales["Price"].str.replace('[\$\,]|\.\d*', '',regex=True).astype(int)

# %%
# car_sales["Price"].str.replace('[\$\,]', '',regex=True).astype(int)

# %%
car_sales["Sales Date"] = pd.date_range("1/1/2022", periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car_sales["Toltal Sales"] = car_sales["Price"].cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Toltal Sales
# 0  Toyota  White         150043      4   4000 2022-01-01          4000
# 1   Honda    Red          87899      4   5000 2022-01-02          9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03         16000
# 3     BMW  Black          11179      5  22000 2022-01-04         38000
# 4  Nissan  White         213095      4   3500 2022-01-05         41500
# 5  Toyota  Green          99213      4   4500 2022-01-06         46000
# 6   Honda   Blue          45698      4   7500 2022-01-07         53500
# 7   Honda   Blue          54738      4   7000 2022-01-08         60500
# 8  Toyota  White          60000      4   6250 2022-01-09         66750
# 9  Nissan  White          31600      4   9700 2022-01-10         76450

# %%
car_sales.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Sales Date", y="Toltal Sales")
# Out:
# <AxesSubplot:xlabel='Sales Date'>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="bar")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)'>

# %%
x = np.random.rand(10, 4)

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.766089  0.688135  0.529704  0.985266
# 1  0.542430  0.337900  0.372180  0.895395
# 2  0.440641  0.107281  0.202277  0.081385
# 3  0.715438  0.056939  0.276395  0.011213
# 4  0.453054  0.076375  0.110360  0.092850
# 5  0.177797  0.068843  0.965201  0.084110
# 6  0.941059  0.853914  0.973856  0.367182
# 7  0.179369  0.055111  0.269678  0.578851
# 8  0.967230  0.467984  0.333820  0.868801
# 9  0.773745  0.677046  0.471280  0.150814

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>]], dtype=object)

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=40);

# %%
heart_disease = pd.read_csv('heart-disease.csv')

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease['age'].plot.hist(bins=20);

# %%
heart_disease.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,20), subplots=True);

# %%
over_50 = heart_disease[heart_disease['age'] >= 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot(x='age', y='chol', c='target', kind='scatter')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
fix, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax)
ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %%
fix, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])

ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
# Out:
# [Text(0.5, 1.0, 'Heart Disease and Cholesterol Levels'),
#  Text(0.5, 0, 'Age'),
#  Text(0, 0.5, 'Cholesterol')]

# %%
fix, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])

ax.legend(*scatter.legend_elements() ,title="Target")

ax.axhline(y=over_50["chol"].mean(), linestyle='--')
